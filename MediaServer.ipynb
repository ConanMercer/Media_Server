# %%
# visualisation
import matplotlib.pyplot as plt

# data analysis
import numpy as np
import pandas as pd
import seaborn as sns

# style
sns.set_theme(style='whitegrid', palette='deep')

# %%
watts = pd.read_csv('Data\watts.csv')
watts.head()
pie = pd.read_csv('Data\pie.csv')
pie.head()
# Out:
#   hardware  watts  load watts
# 0      pie    2.7         6.4
# 1   server    4.8       151.0

# %%
sns.barplot(x="state", y="watts", data=watts).set_title('Server watt consumption')
# Out:
# Text(0.5, 1.0, 'Server watt consumption')

# %%
sns.barplot(x="hardware", y="watts", data=pie).set_title('Server sleep and Raspberry Pi 4 idle watt consumption')
# Out:
# Text(0.5, 1.0, 'Server sleep and Raspberry Pi 4 idle watt consumption')

# %%
sns.barplot(x="hardware", y="load watts", data=pie).set_title('Server load and Raspberry Pi 4 load watt consumption')
# Out:
# Text(0.5, 1.0, 'Server load and Raspberry Pi 4 load watt consumption')

# %%
wattsUndervolting = pd.read_csv('Data\wattsAfterUnderVolting.csv')
sns.barplot(x="state", y="watts", data=wattsUndervolting).set_title('Server watt consumption after undervolting')
# Out:
# Text(0.5, 1.0, 'Server watt consumption after undervolting')

# %%
wattsUndervoltingCompare = pd.read_csv('Data\wattsAfterUnderVoltingCompare.csv')
sns.barplot(x="state", y="watts", data=wattsUndervoltingCompare).set_title('Server watt consumption before and after undervolting')
# Out:
# Text(0.5, 1.0, 'Server watt consumption before and after undervolting')
